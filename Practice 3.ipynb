# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn import preprocessing
# %matplotlib inline

# %%
df = pd.read_csv("shark_tank.csv")

# %%
arr =  np.array(df)

# %%
arr
# Out:
# array([[False, 'Bluetooth device implant for your ear.', 1, ...,
#         'Ionic Ear', '1-1', False],
#        [True,
#         'Retail and wholesale pie factory with two retail locations in New Jersey.',
#         1, ..., "Mr. Tod's Pie Factory", '1-1', False],
#        [True,
#         'Ava the Elephant is a godsend for frazzled parents of young children everywhere. This talking medicine dispenser makes it easy to administer medicine to little ones by turning the experience more playful and by providing positive reinforcement.',
#         1, ..., 'Ava the Elephant', '1-1', False],
#        ...,
#        [True,
# ...

# %%
df
# Out:
#       deal                                        description  episode  \
# 0    False             Bluetooth device implant for your ear.        1
# 1     True  Retail and wholesale pie factory with two reta...        1
# 2     True  Ava the Elephant is a godsend for frazzled par...        1
# 3    False  Organizing, packing, and moving services deliv...        1
# 4    False  Interactive media centers for healthcare waiti...        1
# 5     True  One of the first entrepreneurs to pitch on Sha...        2
# 6    False  A mixed martial arts clothing line looking to ...        2
# 7    False  Attach Noted is a detachable "arm" that holds ...        2
# 8    False  A safety device for seatbelts. It prevents the...        2
# 9     True  An educational record label and publishing hou...        2
# 10    True  A battery-operated cooking device that siphons...        3
# 11   False  Household items with a twist: made from recycl...        3
# ...

# %%
df1 =df.iloc[0:495,7:10]

# %% [markdown]
# scaling

# %%
arr = preprocessing.scale(df1)

# %%
arr
# Out:
# array([[ 1.60801424, -0.25265392,  1.19767157],
#        [ 0.43698653, -0.75012286,  0.64775832],
#        [-0.45212709, -0.25265392, -0.48754636],
#        ...,
#        [-0.3436986 , -1.24759179, -0.04406791],
#        [-0.3436986 ,  0.24481502, -0.44319844],
#        [ 0.09001536, -0.75012286,  0.2220191 ]])

# %%
arr.mean(axis=0),arr.std()
# Out:
# (array([0.00000000e+00, 1.43543987e-17, 2.87087974e-17]), 1.0)

# %%
df1["valuation"].plot(kind = "box")

# %%
df1["exchangeForStake"].plot(kind  = "box")

# %%
df1["askedFor"].plot(kind = "box")

# %% [markdown]
# Nornmalisation

# %%
df2= (df1 - df1.min())/(df1.max()-df1.min())

# %%
df2["askedFor"].plot(kind  ="box")

# %%
df3 =pd.DataFrame(arr)
df3.plot(kind = "kde")

# %%
df2 = preprocessing.scale(df2)

# %%
df2
# Out:
# array([[ 1.60801424, -0.25265392,  1.19767157],
#        [ 0.43698653, -0.75012286,  0.64775832],
#        [-0.45212709, -0.25265392, -0.48754636],
#        ...,
#        [-0.3436986 , -1.24759179, -0.04406791],
#        [-0.3436986 ,  0.24481502, -0.44319844],
#        [ 0.09001536, -0.75012286,  0.2220191 ]])

# %%
df2 =pd.DataFrame(df2).plot(kind = "kde")

# %%
df3 = np.power(df2,1/3)

# %%
df3.plot(kind = "kde")

# %%
df3.mean(),df3.std()
# Out:
# (askedFor            0.317461
#  exchangeForStake    0.502954
#  valuation           0.341729
#  dtype: float64, askedFor            0.123418
#  exchangeForStake    0.123900
#  valuation           0.158092
#  dtype: float64)

# %%
df4 = np.power(df2,1/2)

# %%
df4.mean(),df4.std()
# Out:
# (askedFor            0.188349
#  exchangeForStake    0.365050
#  valuation           0.214812
#  dtype: float64, askedFor            0.119798
#  exchangeForStake    0.129085
#  valuation           0.157653
#  dtype: float64)

# %% [markdown]
# as the values are more closer to 0 in df4 so it is given more priority so taking df4 i.e power = 1/2

# %% [markdown]
# ### Feature Selection

# %% [markdown]
# #### Statstical approach

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
df_num = df.iloc[:,7:11]

# %%
df_num.head()
# Out:
#    askedFor  exchangeForStake  valuation  season
# 0   1000000                15    6666667       1
# 1    460000                10    4600000       1
# 2     50000                15     333333       1
# 3    250000                25    1000000       1
# 4   1200000                10   12000000       1

# %%
selector = VarianceThreshold(10)

# %%
arr2 = selector.fit_transform(df_num)

# %%
df5 =pd.DataFrame(arr2)

# %%
df5.describe()
# Out:
#                   0           1             2
# count  4.950000e+02  495.000000  4.950000e+02
# mean   2.584909e+05   17.539394  2.165615e+06
# std    4.615999e+05   10.061047  3.761971e+06
# min    1.000000e+04    3.000000  4.000000e+04
# 25%    7.500000e+04   10.000000  4.400000e+05
# 50%    1.500000e+05   15.000000  1.000000e+06
# 75%    2.500000e+05   20.000000  2.000000e+06
# max    5.000000e+06  100.000000  3.000000e+07

# %%
df5.head()
# Out:
#          0   1         2
# 0  1000000  15   6666667
# 1   460000  10   4600000
# 2    50000  15    333333
# 3   250000  25   1000000
# 4  1200000  10  12000000

# %% [markdown]
# #### Select Best

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.datasets import load_iris

# %%
df6 = df1

# %%
X,y = df6,df.deal
df_new = SelectKBest(chi2, k =3).fit_transform(X,y)

# %%
df_new.shape
# Out:
# (495, 3)

# %% [markdown]
# ### heatmap

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr())
